# %% [markdown]
# <a href="https://colab.research.google.com/github/hilmi9-cyber/DasarPPLG-X-2627/blob/main/X_PPLG_miftahulhilmi_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# D.Praktik 2 :Menerima input (cin)
# Nama kelompok: Jawa Barat
# Nama anggota:
# 1. Alliyah Herawati
# 2. Hayun Hasanah
# 3. Alvino Setyawan Ramadhan
# 4. Miftahul Hilmi
# 5. Radit Saputra
# 6. M. Shal Alfaraz

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Writing input_data.cpp

# %%
# !g++ input_data.cpp -o input_data
# !./input_data
# Out:
# Masukkan Nama (1 Kata) : hilmi
# Masukkan Umur Anda     : 15
#
# Halo hilmi, ternyata umur kamu 15 tahun ya!
